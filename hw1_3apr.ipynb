# %% [markdown]
# <a href="https://colab.research.google.com/github/MichalSlowakiewicz/NLP/blob/master/hw1_3apr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mim-ml-teaching/public-nlp-2025-26/blob/main/hws/NLP_HW1_Speculative_Decoding.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab">
# </a>
#
# # NLP Homework 1: Speculative Decoding
#
# ## Background
#
# In standard autoregressive transformers, tokens are generated strictly one at a time. Each new token requires a full forward pass, and because generation is causal, the model cannot produce the $k^\text{th}$ token until all preceding tokens have been processed.
#
# This bottleneck is addressed by *Speculative decoding*. A smaller, faster "draft" model first proposes a sequence of candidate tokens. The larger target model then evaluates it in a single forward pass. If the proposed tokens are in fact assigned high-probabilities by a target model then they are accepted, saving additional computation. If some of the proposed tokens are incorrect, the sequence of tokens is rejected at the point of divergence. Although this requires partial recomputation, the larger model has already processed the prefix in parallel.
#
# **Core idea** Given a prefix, a cheap *draft model* proposes $K$ subsequent tokens: $t_1, \dots, t_K$.
# The expensive *target model* is then run **once** on the extended sequence: $[\text{prefix}, t_1, \dots, t_K]$.
# This single forward pass produces logits for all $K+1$ positions in parallel.
#
# **Verification**  The target model ($p_{\text{target}}(\cdot \mid \text{prefix})$) is used to verify the proposed tokens. That is,
# for $i = 1, \dots, K$, we check whether
# $$
# t_i = \arg\max\; p_{\text{target}}(\cdot \mid \text{prefix}, t_1, \dots, t_{i-1}).
# $$
# This can be done in parallel! Now, let $j$ be the largest index such that for all $t_1, \dots, t_j$ the above equality holds. It turns out, we can accept $t_1, \dots, t_j$, discard the rest, and also take the target model's prediction at position $j+1$.
#
# ## Tasks
#
# You will work with WikiText-2 (`wikitext-2-raw-v1`) dataset, and target (verifier) model `google/gemma-3-4b-pt`.
#
#
# ### Task 1: Implement Speculative Decoding Loop (4 pts)
#
# Implement two functions:
#
# 1. **`verify_draft_tensor(context_ids, draft_ids, model)`** - Given a context and a sequence of $K$ draft tokens, run a single forward pass of the target model on the concatenated sequence and determine how many draft tokens match the target model's greedy predictions. Return the accepted prefix plus the target model's next-token prediction. **Your implementation must be fully vectorized (no `for` loops)** to receive maximum number of points.
#
# 2. **`speculative_generate_tensor(context_ids, draft_fn, model, n_tokens, k)`** - The outer generation loop that repeatedly calls the draft function and verifier until `n_tokens` new tokens have been generated. Track and return statistics (e.g., total draft tokens proposed, total accepted, number of verification rounds). Try to avoid device to host transfers in the main loop.
#
# See the code cell below for the exact function signatures.
#
# ### Task 2: Design a Draft Model & Evaluate (4 pts)
#
# Design and implement a **transformer-based** draft model that proposes $K$ candidate tokens given a context. You may either:
#
# - Use a pre-trained small model (e.g., `google/gemma-3-1b-pt`), or
# - Train a small transformer from scratch (e.g., via distillation from the target model, or training directly on `wikitext-2-raw-v1`).
#
# **Deliverables:**
#
# 1. Implement your draft model and wrap it so it conforms to the `draft_fn(context_ids, k)` interface (see `speculative_generate_tensor` argument, or `bigram_draft` function).
# 2. Evaluate on the WikiText-2 **test** split (`test_ds`).
# 3. Report the acceptance rate (fraction of draft tokens accepted by the target model).
# 4. Compare against the provided bigram baseline - your model should achieve a higher acceptance rate.
# 5. Measure wall time of speculative decoding vs standard execution. Your solution should achieve a speedup.
#
# ### Task 3: Visualization & Report (2 pts)
#
# Write a concise summary (≤ 300 words) describing your approach, key findings, and observations.
#
# Your summary should include at least two informative plots. For example you may visualize:
#
# * Speedup vs model size (if you train your own transformer)
# * Acceptance rate vs context length for draft model
# * Histogram of accepted draft lengths
#
# All plots must have axis labels, legends, and titles.

# %%
# added to integrate with Hugging Face + additional imports
from huggingface_hub import login
from google.colab import userdata
import time
import matplotlib.pyplot as plt
import random

login(token=userdata.get('token'))

# %%
import random
import torch
import matplotlib.pyplot as plt
from datasets import load_dataset
from transformers import AutoModelForCausalLM, AutoTokenizer
from collections import defaultdict

random.seed(42)
torch.manual_seed(42)

TARGET_MODEL = "google/gemma-3-4b-pt"

device = "cuda" if torch.cuda.is_available() else "cpu"
dtype  = torch.bfloat16 if device == "cuda" else torch.float32
print(f"Running on: {device}")

def sync():
    if device == "cuda":
        torch.cuda.synchronize()
# Out:
# Running on: cuda

# %%
tokenizer = AutoTokenizer.from_pretrained(TARGET_MODEL)
target_model = AutoModelForCausalLM.from_pretrained(TARGET_MODEL, torch_dtype=dtype).to(device)
target_model.eval()

n_params_target = sum(p.numel() for p in target_model.parameters()) / 1e6
print(f"Target model: {TARGET_MODEL}  ({n_params_target:.0f}M params)  on {device}")

# %%
def autoregressive_generate(context_ids: list[int], n_tokens: int) -> list[int]:
    """Standard autoregressive generation with the target model (baseline)."""
    input_ids = torch.tensor([context_ids], device=device)
    for _ in range(n_tokens):
        logits = target_model(input_ids).logits
        next_tok = logits[:, -1:].argmax(dim=-1)
        input_ids = torch.cat([input_ids, next_tok], dim=1)
    return input_ids[0, len(context_ids):].tolist()

# %%
def get_split(split):
    ds = load_dataset("wikitext", "wikitext-2-raw-v1", split=split)
    examples = [row["text"] for row in ds if row["text"].strip()]
    tokenized_examples = [tokenizer.encode(text, add_special_tokens=False) for text in examples]
    num_tokens = sum(len(tokens) for tokens in tokenized_examples)
    print(f"{split.capitalize()} split: {len(examples):,} examples, {num_tokens:,} tokens in total.")
    return tokenized_examples

train_ds = get_split("train")
test_ds = get_split("test")

# %% [markdown]
# # Naive draft model (bigrams trained on the dataset)

# %%
train_ids = [tok for example in train_ds for tok in example]
bigram_counts = defaultdict(lambda: defaultdict(int))
for id1, id2 in zip(train_ids, train_ids[1:]):
    bigram_counts[id1][id2] += 1

bigram_next = {}
for tok, successors in bigram_counts.items():
    bigram_next[tok] = max(successors, key=successors.get)

fallback_token = tokenizer.encode("the", add_special_tokens=False)[0]

def bigram_draft(context_ids: list[int], k: int) -> list[int]:
    draft = []
    last_tok = context_ids[-1]
    for _ in range(k):
        next_tok = bigram_next.get(last_tok, fallback_token)
        draft.append(next_tok)
        last_tok = next_tok
    return draft

# %%
# Example run

prompt = "The history of artificial"
ctx = tokenizer.encode(prompt, add_special_tokens=False)

draft = bigram_draft(ctx, k=3)
print(f"Context: {prompt!r}")
print(f"Bigram draft: {tokenizer.decode(draft)!r}")
# Out:
# Context: 'The history of artificial'
# Bigram draft: ' intelligence . '

# %% [markdown]
# # Task 1: Implement speculative decoding

# %%
@torch.no_grad()
def verify_draft_tensor(
    context_ids: torch.Tensor,
    draft_ids: torch.Tensor,
    model,
) -> torch.Tensor:
    """
    Verify draft tokens against a model.

    Args:
        context_ids: 1-D tensor (n,) — context tokens.
        draft_ids:   1-D tensor (k,) — drafted token ids to verify.
        model:       the verifier model.

    Returns:
        1-D tensor — verified context + accepted predictions + next token.
    """
    # TODO
    N, K = context_ids.shape[0], draft_ids.shape[0]
    combined = torch.cat([context_ids, draft_ids])
    combined = combined.view(1, N+K)

    # obtaining predictions of the model for new tokens
    logits = model(combined).logits
    predictions = torch.argmax(logits, dim=2).view(N+K)
    predictions_reduced = predictions[-K-1:-1]

    # checking which tokens from draft prediction align with model's prediction
    agreement_vector = torch.zeros_like(draft_ids)
    mask = (predictions_reduced == draft_ids)
    agreement_vector[mask] = 1
    first_zero_index = (agreement_vector == 0).int().argmax().item()

    # returning new tensor up to the point where predictions didn't agree
    if agreement_vector.sum() == K:
      return torch.cat([context_ids, predictions[-K-1:]])
    else:
      return torch.cat([context_ids, predictions[-K-1:-K+first_zero_index]])

@torch.no_grad()
def speculative_generate_tensor(
    context_ids: list[int],
    draft_fn,
    model,
    n_tokens: int,
    k: int,
) -> tuple[list[int], dict]:
    """
    Speculative generation.

    Args:
        context_ids: prefix token ids.
        draft_fn:    callable(sequence_tensor, k) -> (k,) device tensor.
        model:       verifier model.
        n_tokens:    number of tokens to generate.
        k:           speculation length.

    Returns:
        (generated_token_ids, stats_dict)
    """
    # TODO
    total_drafted = 0
    total_accepted = 0
    n_rounds = 0
    current_sequence = torch.tensor(context_ids, device=device, dtype=torch.long)
    desired_length = len(context_ids) + n_tokens

    # loop for sequential generation using the draft model
    while len(current_sequence) < desired_length:
      new_tokens_draft = draft_fn(current_sequence, k)
      verified_tensor = verify_draft_tensor(current_sequence, new_tokens_draft, model)
      total_drafted += k
      total_accepted += len(verified_tensor) - 1 - len(current_sequence)
      n_rounds += 1
      current_sequence = verified_tensor

    # extracting only new tokens
    results_tensor = verified_tensor[len(context_ids):]

    # protection if we generated more than n new tokens
    if len(results_tensor) > n_tokens:
      results_tensor = results_tensor[:n_tokens]

    # preparing dictionary with statistics
    stats_dict = {'Tokens drafted': total_drafted, 'Tokens accepted': total_accepted, 'Number of rounds': n_rounds}
    results_list = results_tensor.tolist()

    return results_list, stats_dict

# %% [markdown]
# # Task 2: Evaluate speculative decoding

# %%
# TODO

# %%
# importing smaller draft model
DRAFT_MODEL = "google/gemma-3-1b-pt"
draft_model = AutoModelForCausalLM.from_pretrained(DRAFT_MODEL, torch_dtype=dtype).to(device)
draft_model.eval()

# %%
def draft_function(sequence_tensor, k):
  sequence_tensor = sequence_tensor.view(1, -1)

  with torch.no_grad():
    # 'num_beams=1' and 'do_sample=False' were added to set greedy prediction type
    model_output = draft_model.generate(inputs=sequence_tensor, max_new_tokens=k, num_beams=1, do_sample=False) # this returns original context + new tokens

  # reducing output only to new tokens
  new_tokens = model_output[:, -k:]
  new_tokens = new_tokens.view(-1)

  return new_tokens

# %%
# evaluation function
@torch.no_grad()
def evaluation_function(n_new_tokens, test_ds, draft_function, k):
  """
  Evaluation function, which returns 6 statistics:
  (acceptance_rate, avg_time_standard, avg_time_speculative_decoding, avg_time_diff, context_lengths, sequence_acceptance_rates)
  """
  # initializing variables and lists
  total_drafted_all = 0
  total_accepted_all = 0
  n_rounds_all = 0
  time_diffs = []
  times_standard = []
  times_speculative_decoding = []
  context_lengths = []
  sequence_acceptance_rates = []

  # main loop across the test dataset
  for context in test_ds:

    # speculative decoding with the use of draft model
    sync()
    t1_start = time.time()
    generated_tokens_speculative_decoding, stats_dict = speculative_generate_tensor(context_ids=context, draft_fn=draft_function, model=target_model, n_tokens=n_new_tokens, k=k)
    sync()
    t1_end = time.time()
    t1 = t1_end - t1_start

    # standard autoregressive method
    sync()
    t2_start = time.time()
    generated_tokens_standard = autoregressive_generate(context, n_new_tokens)
    sync()
    t2_end = time.time()
    t2 = t2_end - t2_start

    # updating lists and statistics
    time_diffs.append(t1-t2)
    times_standard.append(t2)
    times_speculative_decoding.append(t1)

    drafted = stats_dict['Tokens drafted']
    accepted = stats_dict['Tokens accepted']

    context_lengths.append(len(context))
    sequence_acceptance_rates.append(accepted / drafted if drafted > 0 else 0)

    total_drafted_all += drafted
    total_accepted_all += accepted
    n_rounds_all += stats_dict['Number of rounds']

    # added to save VRAM
    torch.cuda.empty_cache()

  # calculating final statistics
  acceptance_rate = total_accepted_all / total_drafted_all
  avg_time_standard = sum(times_standard) / len(times_standard)
  avg_time_speculative_decoding = sum(times_speculative_decoding) / len(times_speculative_decoding)
  avg_time_diff = sum(time_diffs) / len(time_diffs)

  print("Acceptance rate:", acceptance_rate)
  print("Average time (standard approach):", avg_time_standard)
  print("Average time (speculative decoding approach):", avg_time_speculative_decoding)
  print("Average time difference (speculative decoding - standard time):", avg_time_diff)

  return acceptance_rate, avg_time_standard, avg_time_speculative_decoding, avg_time_diff, context_lengths, sequence_acceptance_rates

# %%
test_set=random.sample(test_ds, 200)

# %%
acceptance_rate_gemma, avg_time_standard_gemma, avg_time_speculative_decoding_gemma, avg_time_diff_gemma, context_lengths_gemma, sequence_acceptance_rates_gemma  = evaluation_function(n_new_tokens=30, test_ds=test_set, draft_function=draft_function, k=5)
# Out:
# The following generation flags are not valid and may be ignored: ['top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Acceptance rate: 0.9413207547169812
# Average time (standard approach): 16.49866795897484
# Average time (speculative decoding approach): 4.951368162631988
# Average time difference (speculative decoding - standard time): -11.54729979634285

# %%
def bigram_draft_adjusted(sequence_tensor, k):
  """
  Wrapper function for Bigram draft model.
  Ensures compatibility with 'evaluation_function'.
  """
  sequence_list = sequence_tensor.tolist()
  draft = bigram_draft(sequence_list, k)
  draft_tensor = torch.tensor(draft, dtype=torch.long, device=device)
  return draft_tensor

# %%
acceptance_rate_bigram, avg_time_standard_bigram, avg_time_speculative_decoding_bigram, avg_time_diff_bigram, context_lengths_bigram, sequence_acceptance_rates_bigram = evaluation_function(n_new_tokens=30, test_ds=test_set, draft_function=bigram_draft_adjusted, k=5)
# Out:
# Acceptance rate: 0.0022581732389619145
# Average time (standard approach): 16.500347006320954
# Average time (speculative decoding approach): 16.791907925605773
# Average time difference (speculative decoding - standard time): 0.29156091928482053

# %%
len(test_ds)
# Out:
# 2891

# %%
for i, t in enumerate(test_set):
  context_tail = t[-10:] if len(t) > 10 else t
  context_text = tokenizer.decode(context_tail)

  draft_ids = bigram_draft(t, k=5)
  draft_text = tokenizer.decode(draft_ids)

  print(f'Example {i+1}')
  print(f'Context: ...{context_text}')
  print(f'Bigram prediction: {draft_text}')
  print('- ' * 100)
# Out:
# Example 1
# Context: ... deliberately ambiguous about the cause of death .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 2
# Context: ... = = = Legacy = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 3
# Context: ...bin Nedler — writing , background vocals
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 4
# Context: ... campaign , in the middle Danube valley .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 5
# Context: ... Chan @-@ hom = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 6
# Context: ... , Ambassador Bishop declared the evacuation complete .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 7
# Context: ... Suborder Euskelia
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 8
# Context: ... to fall out of shape than wood .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 9
# Context: ... , and his feelings about the task .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 10
# Context: ...1 the Provisional IRA remained numerically small .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 11
# Context: ... molten metal for extra incendiary power .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 12
# Context: ... one punch that he thought looked fake .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 13
# Context: ... to rub it in your face . "
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 14
# Context: ... = = = Protection = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 15
# Context: ... generators at 225 volts .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 16
# Context: ... for all @-@ round fire .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 17
# Context: ... mission was delayed until 5 January .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 18
# Context: ... , distribution was handled by Warner Music .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 19
# Context: ...s Chinese @-@ Filipino community .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 20
# Context: ... 78 south of the city .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 21
# Context: ... = = Release history = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 22
# Context: ... entire world is a suburb of Manhattan .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 23
# Context: ...1949 Head series = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 24
# Context: ... = = Design = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 25
# Context: ... loser because he 's dead inside .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 26
# Context: ... later left to join the Provisionals .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 27
# Context: ...0 ° C during the lunar night .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 28
# Context: ... the helicopter landing zone ( HLZ )
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 29
# Context: ... still owns today ) the Lowell canals .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 30
# Context: ... fingerprints were found all over the investigation .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 31
# Context: ... = = = Dispositions = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 32
# Context: ... about by massive floods in the region .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 33
# Context: ...5 - T8.0 ) .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 34
# Context: ... to learn that she has killed herself .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 35
# Context: ... . He does , and they kiss .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 36
# Context: ... sections until the desired response was obtained .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 37
# Context: ...-@ sight between the two towns .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 38
# Context: ... to that of living amphibians and reptiles .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 39
# Context: ... = = Background = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 40
# Context: ... Championship ( 4 times ) 2
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 41
# Context: ... long @-@ range cruising warships .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 42
# Context: ... Italian attracted great attention in following years .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 43
# Context: ... this major theme of Olmec art .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 44
# Context: ... a round every 15 minutes .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 45
# Context: ... " that she did not look injured .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 46
# Context: ... image impedances of the section are given by
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 47
# Context: ... = = Lockport area = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 48
# Context: ...ination of carbonyls ( B ) .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 49
# Context: ... Hart , who played the same position .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 50
# Context: ... ordered her out of the imperial residence .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 51
# Context: ... Frederick Warde as Ezra Greer
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 52
# Context: ... = = Background and publication = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 53
# Context: ... the stone to these sites remain unclear .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 54
# Context: ...4 – 2003 )
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 55
# Context: ... are and why you do this . "
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 56
# Context: ... World Wrestling Federation / Entertainment = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 57
# Context: ... is Prince Edward , Duke of Kent .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 58
# Context: ... Roll Bounce
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 59
# Context: ... = = History = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 60
# Context: ... = = Public transportation = = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 61
# Context: ... is a Methodist with strong religious faith .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 62
# Context: ...0th Anniversary Edition ) - Nominated
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 63
# Context: ... which were no longer of strategic importance .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 64
# Context: ... = = Meteorological history = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 65
# Context: ... SM UB @-@ 17
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 66
# Context: ... = = Regular season = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 67
# Context: ... Maltitz , nine battalions of infantry .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 68
# Context: ...4 – 2015 )
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 69
# Context: ... = = Production and recording = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 70
# Context: ... torpedo attack by a boat less suicidal .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 71
# Context: ... reporting on Nero 's tyrannical acts .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 72
# Context: ...-@ war military and civilian graves .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 73
# Context: ...th Airborne Armoured Reconnaissance Regiment .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 74
# Context: ... = = Usage = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 75
# Context: ... divisions as not suitable for further service .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 76
# Context: ... = = Production = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 77
# Context: ... that does not contribute to the presentation .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 78
# Context: ... last by Vichy forces on Gibraltar .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 79
# Context: ... Et ) CONH + H2O
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 80
# Context: ... responded by stepping up its promotional activities .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 81
# Context: ... the Nerva – Antonine dynasty .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 82
# Context: ... feast day is 30 July .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 83
# Context: ... = = History = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 84
# Context: ... = = History = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 85
# Context: ... these is the Thiepval Memorial .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 86
# Context: ... der Sar and Tomasz Kuszczak .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 87
# Context: ...alerata in the Brazilian Pantanal .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 88
# Context: ... Kujira resulted in three fatalities .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 89
# Context: ... INCREASED TO 30 KT .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 90
# Context: ... by his dead wife 's name .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 91
# Context: ... developed in a lowland tropical forest setting .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 92
# Context: ... of unactivated hydrocarbons = = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 93
# Context: ... = = = Horticulture = = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 94
# Context: ... = = = Administration = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 95
# Context: ... are within the athlete 's heat only
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 96
# Context: ... , but scattered as the helicopters arrived .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 97
# Context: ... @-@ granddaughter of Tiberius .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 98
# Context: ... = = Mixed martial arts record = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 99
# Context: ...oon bridges for their vehicles and armor .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 100
# Context: ... = = Finals series = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 101
# Context: ... were 305 mm thick .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 102
# Context: ... Fallaway slam
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 103
# Context: ... lead our program , " Collier remarked .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 104
# Context: ... = = = Oxygen transfer = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 105
# Context: ... chances of capturing Yongsan were strong .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 106
# Context: ... of copies were returned to the publisher .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 107
# Context: ... @-@ war period = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 108
# Context: ... – 2012 – present
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 109
# Context: ...0th @-@ century poetry .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 110
# Context: ... stationed there during the Russian Civil War .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 111
# Context: ... order to adapt to the frequent earthquakes .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 112
# Context: ... Academic All @-@ America nominee .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 113
# Context: ... , Turkey , United Arab Emirates and Yemen
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 114
# Context: ... proclamation as an adult had been set .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 115
# Context: ... Family Archegosauridae
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 116
# Context: ... to configurationally stable nitrogen are reported .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 117
# Context: ... , making it a severe tropical storm .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 118
# Context: ... = = Parodies = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 119
# Context: ... = = Release and reception = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 120
# Context: ... possibility of chirality at the nitrogen center .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 121
# Context: ... vegetables , fruits , food and drinks .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 122
# Context: ... Cybill — into writing American Beauty .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 123
# Context: ... = = Other attractions = = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 124
# Context: ... Stevens ' time as an assistant coach .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 125
# Context: ... = = World War II = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 126
# Context: ... and first evacuees = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 127
# Context: ... Order Temnospondyli
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 128
# Context: ... seen as hindrances for its growth .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 129
# Context: ... transshipped via Mexico towards Manila .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 130
# Context: ... Morgan , CSS Gaines , CSS Selma .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 131
# Context: ... planes , and most docks were wrecked .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 132
# Context: ... started a new era of naval warfare .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 133
# Context: ... deposit in which the eggs were found .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 134
# Context: ... a 2 @.@ 0 .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 135
# Context: ...ography Command in Pearl Harbor , Hawaii .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 136
# Context: ... and escorted by Polish Servicemen .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 137
# Context: ... plastic bag being blown in the wind .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 138
# Context: ... men and women in the synagogue . "
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 139
# Context: ... carriers being used at this crossing site .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 140
# Context: ... 27 irregularly spaced artificial depressions .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 141
# Context: ... the very concept of rulership itself .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 142
# Context: ... over the Israeli – Palestinian conflict , and
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 143
# Context: ... choice to perform , calling it shameful .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 144
# Context: ...-@ brown or purple when mature .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 145
# Context: ... responsible for the deaths of four persons .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 146
# Context: ... , all music composed by Stone Sour .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 147
# Context: ... = = = Moral engagement = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 148
# Context: ... 's daughter , were never found .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 149
# Context: ... as bearing resemblance to ironclads .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 150
# Context: ... again until 1951 .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 151
# Context: ... Curran as Denbeigh 's guardian
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 152
# Context: ... ketone to give the oxaziridine :
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 153
# Context: ... = = Organisation = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 154
# Context: ... being called up to the main roster .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 155
# Context: ... image closer to what he originally intended .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 156
# Context: ...5 and 1180 .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 157
# Context: ... = = Early life = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 158
# Context: ... = = = Theatre = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 159
# Context: ... N @-@ acylamidation .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 160
# Context: ... riverside , along with stricter pollution controls .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 161
# Context: ... the 2010 draft .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 162
# Context: ... has its regional office along UN Avenue .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 163
# Context: ... sailing rig on ironclad battleships .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 164
# Context: ... Australian competitor in her event and class .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 165
# Context: ... re @-@ signed with WWE .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 166
# Context: ... = = Headstones = = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 167
# Context: ... Hometown Hero Award from the Honeywell Corp.
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 168
# Context: ...945 , when production ended .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 169
# Context: ... = = = Pattern types = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 170
# Context: ... " Because she is his wife " .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 171
# Context: ... Scheelea and Orbignya .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 172
# Context: ... Mercenaries directed by Paris Leonti .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 173
# Context: ...29th Avenue building = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 174
# Context: ... 2013 – present )
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 175
# Context: ... not to persecute any more Christians .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 176
# Context: ... = = Composition and reception = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 177
# Context: ... = = Today = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 178
# Context: ... make some bombing raids and supply drops .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 179
# Context: ...ll see me in the octagon " .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 180
# Context: ... = = Certifications = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 181
# Context: ... B Company lost heavily in this action .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 182
# Context: ... = = Seasonal forecasts = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 183
# Context: ... decade before the first ironclads .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 184
# Context: ... Nero in Jewish and Christian tradition = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 185
# Context: ... = = North Korean withdrawal = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 186
# Context: ... to their fire @-@ tolerance .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 187
# Context: ... = = Adaptations = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 188
# Context: ... the United Kingdom and the United States .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 189
# Context: ... SM UB @-@ 11
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 190
# Context: ... but were bribed to overthrow him .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 191
# Context: ... = = Production = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 192
# Context: ... York State Route 31B =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 193
# Context: ...onyloxaziridines = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 194
# Context: ... = = North America = = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 195
# Context: ... between North Ridge and Lower Mountain Road .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 196
# Context: ... = = Themes and analysis = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 197
# Context: ... Amy @-@ gism . "
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 198
# Context: ... had made the improbable story more plausible .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 199
# Context: ... = = Crisis of succession = = =
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Example 200
# Context: ... or off , curtains open or closed .
#
# Bigram prediction:  = = = = =
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# # Task 3: Visualization & Report

# %%
# TODO: Your plots

# %%
# Plot 1: Acceptance Rate comparison
draft_models = ["Bigram (Baseline)", "Gemma 1B"]
results = [acceptance_rate_bigram, acceptance_rate_gemma]

plt.figure(figsize=(12,6))
plt.bar(draft_models, results, color=['red', 'blue'])
plt.title("Acceptance Rate comparison: Bigram vs Gemma")
plt.ylabel("Acceptance Rate")
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Plot 2: Average generation time
methods = ['Standard AR', 'SD Bigram', 'SD Gemma']
results = [(avg_time_standard_gemma + avg_time_standard_bigram) / 2, avg_time_speculative_decoding_bigram, avg_time_speculative_decoding_gemma]

plt.figure(figsize=(12,6))
plt.bar(methods, results, color=['green', 'red', 'blue'])
plt.title("Average generation time for 30 new tokens")
plt.ylabel("Time (seconds)")
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Plot 3.1: Acceptance rate vs context length (Gemma)
plt.figure(figsize=(12,6))
plt.scatter(context_lengths_gemma, sequence_acceptance_rates_gemma, alpha=0.7, color='blue')
plt.title("Acceptance rate vs context length for draft model Gemma")
plt.xlabel("Context length")
plt.ylabel("Acceptance Rate")
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Plot 3.2: Acceptance rate vs context length (Bigram)
plt.figure(figsize=(12,6))
plt.scatter(context_lengths_bigram, sequence_acceptance_rates_bigram, alpha=0.7, color='red')
plt.title("Acceptance rate vs context length for draft model Bigram (Baseline)")
plt.xlabel("Context length")
plt.ylabel("Acceptance Rate")
plt.grid(True, alpha=0.3)
plt.show()

# %%
# short experiment to examine the impact of 'k' parameter on Acceptance Rate and Average Time
k_values = [2, 4, 6, 8, 10]
results_acceptance_rate = []
results_average_time = []
test_set=random.sample(test_ds, 20)

for k in k_values:
  acceptance_rate_gemma_experiment, _, avg_time_speculative_decoding_experiment, _, _, _ = evaluation_function(n_new_tokens=30, test_ds=test_set, draft_function=draft_function, k=k)
  results_acceptance_rate.append(acceptance_rate_gemma_experiment)
  results_average_time.append(avg_time_speculative_decoding_experiment)

# Plot 4: Impact of K - Acceptance Rate
plt.figure(figsize=(12,6))
plt.plot(k_values, results_acceptance_rate, marker='o', linestyle='-', color='orange')
plt.title("Impact of parameter K on Acceptance Rate")
plt.xlabel("Parameter K")
plt.ylabel("Average Acceptance Rate")
plt.xticks(k_values)
plt.grid(True, alpha=0.3)
plt.show()

# Plot 5: Impact of K - Average Time
plt.figure(figsize=(12,6))
plt.plot(k_values, results_average_time, marker='o', linestyle='-', color='blue')
plt.title("Impact of parameter K on Average Time")
plt.xlabel("Parameter K")
plt.ylabel("Average Time (seconds)")
plt.xticks(k_values)
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Acceptance rate: 0.9950248756218906
# Average time (standard approach): 14.600082409381866
# Average time (speculative decoding approach): 6.876130378246307
# Average time difference (speculative decoding - standard time): -7.723952031135559
# Acceptance rate: 0.9917355371900827
# Average time (standard approach): 14.6148206949234
# Average time (speculative decoding approach): 4.94180520772934
# Average time difference (speculative decoding - standard time): -9.67301548719406
# Acceptance rate: 0.9900990099009901
# Average time (standard approach): 14.64216068983078
# Average time (speculative decoding approach): 4.8957473039627075
# Average time difference (speculative decoding - standard time): -9.746413385868072
# Acceptance rate: 0.9876543209876543
# Average time (standard approach): 14.621476531028748
# Average time (speculative decoding approach): 4.369332587718963
# Average time difference (speculative decoding - standard time): -10.252143943309784
# Acceptance rate: 0.9836065573770492
# Average time (standard approach): 14.629032421112061
# Average time (speculative decoding approach): 3.579939603805542
# Average time difference (speculative decoding - standard time): -11.04909281730652

# %% [markdown]
# *TODO: Write your report here.*
